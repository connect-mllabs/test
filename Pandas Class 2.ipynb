# %%
import pandas as pd
import numpy as np
##### version compatability : ignore all the warnings in the jupyter notebook
import warnings
warnings.filterwarnings("ignore")

# %%
### Set 1 : functions

# %%
df1=pd.DataFrame([1,2,3])
df2=pd.DataFrame(np.random.randint(0,10,(3,3)))
df3=pd.DataFrame([{"a":20,"b":40,"c":50}])

# %%
df3
# Out:
#     a   b   c
# 0  20  40  50

# %%
#### read_csv
#### csv/excel
#### Databases
#### irrespective of type of method used final outcome is always a data frame

# %%
df=pd.read_csv("D:/ML LABS 2.0/datasets/kaggle_survey_2021_responses.csv")

# %%
df ### simple variable will show top 5 and bottom 5
# Out:
#                           zr                           Q1  \
# 0      Duration (in seconds)  What is your age (# years)?
# 1                        161                        25-29
# 2                       1024                        22-24
# 3                       2176                        25-29
# 4                       1112                        45-49
# ...                      ...                          ...
# 25969                    636                        35-39
# 25970                    358                        22-24
# 25971                    391                        18-21
# 25972                    527                        25-29
# 25973                    217                        22-24
#
#                                            Q2  \
# 0      What is your gender? - Selected Choice
# 1                                         Man
# 2                                         Man
# 3                                         Man
# ...

# %%
df.shape
# Out:
# (25974, 369)

# %%
df.columns
# Out:
# Index(['zr', 'Q1', 'Q2', 'Q3', 'Q4', 'Q5', 'Q6', 'Q7_Part_1', 'Q7_Part_2',
#        'Q7_Part_3',
#        ...
#        'Q38_B_Part_3', 'Q38_B_Part_4', 'Q38_B_Part_5', 'Q38_B_Part_6',
#        'Q38_B_Part_7', 'Q38_B_Part_8', 'Q38_B_Part_9', 'Q38_B_Part_10',
#        'Q38_B_Part_11', 'Q38_B_OTHER'],
#       dtype='object', length=369)

# %%
list(df.columns)
# Out:
# ['zr',
#  'Q1',
#  'Q2',
#  'Q3',
#  'Q4',
#  'Q5',
#  'Q6',
#  'Q7_Part_1',
#  'Q7_Part_2',
#  'Q7_Part_3',
#  'Q7_Part_4',
#  'Q7_Part_5',
#  'Q7_Part_6',
#  'Q7_Part_7',
#  'Q7_Part_8',
#  'Q7_Part_9',
#  'Q7_Part_10',
#  'Q7_Part_11',
#  'Q7_Part_12',
#  'Q7_OTHER',
#  'Q8',
#  'Q9_Part_1',
#  'Q9_Part_2',
#  'Q9_Part_3',
#  'Q9_Part_4',
#  'Q9_Part_5',
#  'Q9_Part_6',
#  'Q9_Part_7',
#  'Q9_Part_8',
#  'Q9_Part_9',
#  'Q9_Part_10',
#  'Q9_Part_11',
#  'Q9_Part_12',
#  'Q9_OTHER',
#  'Q10_Part_1',
#  'Q10_Part_2',
#  'Q10_Part_3',
#  'Q10_Part_4',
#  'Q10_Part_5',
#  'Q10_Part_6',
#  'Q10_Part_7',
#  'Q10_Part_8',
#  'Q10_Part_9',
#  'Q10_Part_10',
#  'Q10_Part_11',
#  'Q10_Part_12',
#  'Q10_Part_13',
#  'Q10_Part_14',
#  'Q10_Part_15',
#  'Q10_Part_16',
#  'Q10_OTHER',
#  'Q11',
#  'Q12_Part_1',
#  'Q12_Part_2',
#  'Q12_Part_3',
#  'Q12_Part_4',
#  'Q12_Part_5',
#  'Q12_OTHER',
#  'Q13',
#  'Q14_Part_1',
#  'Q14_Part_2',
#  'Q14_Part_3',
#  'Q14_Part_4',
#  'Q14_Part_5',
# ...

# %%
for i in df.columns:
    print(i)
# Out:
# zr
# Q1
# Q2
# Q3
# Q4
# Q5
# Q6
# Q7_Part_1
# Q7_Part_2
# Q7_Part_3
# Q7_Part_4
# Q7_Part_5
# Q7_Part_6
# Q7_Part_7
# Q7_Part_8
# Q7_Part_9
# Q7_Part_10
# Q7_Part_11
# Q7_Part_12
# Q7_OTHER
# Q8
# Q9_Part_1
# Q9_Part_2
# Q9_Part_3
# Q9_Part_4
# Q9_Part_5
# Q9_Part_6
# Q9_Part_7
# Q9_Part_8
# Q9_Part_9
# Q9_Part_10
# Q9_Part_11
# Q9_Part_12
# Q9_OTHER
# Q10_Part_1
# Q10_Part_2
# Q10_Part_3
# Q10_Part_4
# Q10_Part_5
# Q10_Part_6
# Q10_Part_7
# Q10_Part_8
# Q10_Part_9
# Q10_Part_10
# Q10_Part_11
# Q10_Part_12
# Q10_Part_13
# Q10_Part_14
# Q10_Part_15
# Q10_Part_16
# Q10_OTHER
# Q11
# Q12_Part_1
# Q12_Part_2
# Q12_Part_3
# Q12_Part_4
# Q12_Part_5
# Q12_OTHER
# Q13
# Q14_Part_1
# Q14_Part_2
# Q14_Part_3
# Q14_Part_4
# Q14_Part_5
# Q14_Part_6
# Q14_Part_7
# Q14_Part_8
# Q14_Part_9
# Q14_Part_10
# Q14_Part_11
# Q14_OTHER
# Q15
# Q16_Part_1
# Q16_Part_2
# Q16_Part_3
# Q16_Part_4
# Q16_Part_5
# Q16_Part_6
# Q16_Part_7
# Q16_Part_8
# Q16_Part_9
# Q16_Part_10
# Q16_Part_11
# Q16_Part_12
# ...

# %%
df.index ### default index ### 0,25974,1
# Out:
# RangeIndex(start=0, stop=25974, step=1)

# %%
### int
### float
### object

### Cat (Object with less unique values)

df.dtypes
# Out:
# zr               object
# Q1               object
# Q2               object
# Q3               object
# Q4               object
#                   ...
# Q38_B_Part_8     object
# Q38_B_Part_9     object
# Q38_B_Part_10    object
# Q38_B_Part_11    object
# Q38_B_OTHER      object
# Length: 369, dtype: object

# %%
df.index
df.columns
df.shape
df.dtypes
df.values ### for any data frame .values it becomes numpy array
# Out:
# array([['Duration (in seconds)', 'What is your age (# years)?',
#         'What is your gender? - Selected Choice', ...,
#         'In the next 2 years, do you hope to become more familiar with any of these tools for managing ML experiments? (Select all that apply) - Selected Choice -  MLflow ',
#         'In the next 2 years, do you hope to become more familiar with any of these tools for managing ML experiments? (Select all that apply) - Selected Choice - None',
#         'In the next 2 years, do you hope to become more familiar with any of these tools for managing ML experiments? (Select all that apply) - Selected Choice - Other'],
#        ['161', '25-29', 'Man', ..., nan, nan, nan],
#        ['1024', '22-24', 'Man', ..., nan, 'None', nan],
#        ...,
#        [391, '18-21', 'Woman', ..., nan, nan, nan],
#        [527, '25-29', 'Woman', ..., nan, nan, nan],
#        [217, '22-24', 'Woman', ..., nan, nan, nan]], dtype=object)

# %%
#### Set 2

# %%
df.head(2) ### top 5 rows
# Out:
#                       zr                           Q1  \
# 0  Duration (in seconds)  What is your age (# years)?
# 1                    161                        25-29
#
#                                        Q2  \
# 0  What is your gender? - Selected Choice
# 1                                     Man
#
#                                           Q3  \
# 0  In which country do you currently reside?
# 1                                    Algeria
#
#                                                   Q4  \
# 0  What is the highest level of formal education ...
# 1                             Professional doctorate
#
#                                                   Q5  \
# 0  Select the title most similar to your current ...
# 1                                            Student
#
#                                                   Q6  \
# 0  For how many years have you been writing code ...
# 1                          I have never written code
#
# ...

# %%
df.tail(2) ### top 5 rows
# Out:
#         zr     Q1     Q2        Q3                 Q4       Q5  \
# 25972  527  25-29  Woman  Viet Nam    Master’s degree    Other
# 25973  217  22-24  Woman  Viet Nam  Bachelor’s degree  Student
#
#                               Q6 Q7_Part_1 Q7_Part_2 Q7_Part_3  ...  \
# 25972                  1-3 years    Python       NaN       SQL  ...
# 25973  I have never written code       NaN       NaN       NaN  ...
#
#       Q38_B_Part_3          Q38_B_Part_4   Q38_B_Part_5 Q38_B_Part_6  \
# 25972          NaN   Sacred + Omniboard    TensorBoard           NaN
# 25973          NaN                   NaN            NaN          NaN
#
#       Q38_B_Part_7 Q38_B_Part_8 Q38_B_Part_9 Q38_B_Part_10 Q38_B_Part_11  \
# 25972          NaN          NaN          NaN           NaN           NaN
# 25973          NaN          NaN          NaN           NaN           NaN
#
#       Q38_B_OTHER
# 25972         NaN
# 25973         NaN
#
# [2 rows x 369 columns]

# %%
df.index
# Out:
# RangeIndex(start=0, stop=25974, step=1)

# %%
df.values.shape
# Out:
# (25974, 369)

# %%
df.values[0,0:]
# Out:
# array(['Duration (in seconds)', 'What is your age (# years)?',
#        'What is your gender? - Selected Choice',
#        'In which country do you currently reside?',
#        'What is the highest level of formal education that you have attained or plan to attain within the next 2 years?',
#        'Select the title most similar to your current role (or most recent title if retired): - Selected Choice',
#        'For how many years have you been writing code and/or programming?',
#        'What programming languages do you use on a regular basis? (Select all that apply) - Selected Choice - Python',
#        'What programming languages do you use on a regular basis? (Select all that apply) - Selected Choice - R',
#        'What programming languages do you use on a regular basis? (Select all that apply) - Selected Choice - SQL',
#        'What programming languages do you use on a regular basis? (Select all that apply) - Selected Choice - C',
# ...

# %%
#### numpy : rows, columns

# %%
df.head(2)
# Out:
#                       zr                           Q1  \
# 0  Duration (in seconds)  What is your age (# years)?
# 1                    161                        25-29
#
#                                        Q2  \
# 0  What is your gender? - Selected Choice
# 1                                     Man
#
#                                           Q3  \
# 0  In which country do you currently reside?
# 1                                    Algeria
#
#                                                   Q4  \
# 0  What is the highest level of formal education ...
# 1                             Professional doctorate
#
#                                                   Q5  \
# 0  Select the title most similar to your current ...
# 1                                            Student
#
#                                                   Q6  \
# 0  For how many years have you been writing code ...
# 1                          I have never written code
#
# ...

# %%
df[['Q1','Q4']]  ### single column subset - series multiple column subset is data frame
# Out:
#                                 Q1  \
# 0      What is your age (# years)?
# 1                            25-29
# 2                            22-24
# 3                            25-29
# 4                            45-49
# ...                            ...
# 25969                        35-39
# 25970                        22-24
# 25971                        18-21
# 25972                        25-29
# 25973                        22-24
#
#                                                       Q4
# 0      What is the highest level of formal education ...
# 1                                 Professional doctorate
# 2                                 Professional doctorate
# 3                                        Master’s degree
# 4                                        Master’s degree
# ...                                                  ...
# 25969                                    Doctoral degree
# 25970                                  Bachelor’s degree
# ...

# %%
df[['Q1','Q4']][1:4]
# Out:
#       Q1                      Q4
# 1  25-29  Professional doctorate
# 2  22-24  Professional doctorate
# 3  25-29         Master’s degree

# %%
### iloc
### loc

# %%
df=pd.DataFrame(np.random.randint(0,10,(5,5)))
df
# Out:
#    0  1  2  3  4
# 0  6  1  8  6  2
# 1  5  5  4  4  9
# 2  9  6  0  0  9
# 3  2  9  9  8  6
# 4  6  5  3  7  8

# %%
df.iloc[0:3,[2,4]]
# Out:
#    2  4
# 0  8  2
# 1  4  9
# 2  0  9

# %%
df.loc[0:3,2:4] ### the range operator considers last value as well
# Out:
#    2  3  4
# 0  8  6  2
# 1  4  4  9
# 2  0  0  9
# 3  9  8  6

# %%
#### set 2 :
df.head()
df.tail()
subset data
### dataframe
### loc
### iloc

# %%
#### set 3

# %%
kaggle_survey_dataset=pd.read_csv("D:/ML LABS 2.0/datasets/kaggle_survey_2021_responses.csv")

# %%
kaggle_survey_dataset.shape
# Out:
# (25974, 369)

# %%
#### 369 columns

# %%
kaggle_survey_dataset.mean()
# Out:
# Series([], dtype: float64)

# %%
df.mean()
# Out:
# 0    5.6
# 1    5.2
# 2    4.8
# 3    5.0
# 4    6.8
# dtype: float64

# %%
df=pd.DataFrame(np.random.randint(0,10,(5,5)),columns="A B C D E".split())
df.mean()
df.std()
df.var()
df.median()
df.corr()
# Out:
# A    3.4
# B    4.2
# C    4.8
# D    5.0
# E    3.8
# dtype: float64

# %%
kaggle_survey_dataset
# Out:
#                           zr                           Q1  \
# 0      Duration (in seconds)  What is your age (# years)?
# 1                        161                        25-29
# 2                       1024                        22-24
# 3                       2176                        25-29
# 4                       1112                        45-49
# ...                      ...                          ...
# 25969                    636                        35-39
# 25970                    358                        22-24
# 25971                    391                        18-21
# 25972                    527                        25-29
# 25973                    217                        22-24
#
#                                            Q2  \
# 0      What is your gender? - Selected Choice
# 1                                         Man
# 2                                         Man
# 3                                         Man
# ...

# %%
df.columns=['BH','NI','BI','RA','PA']

# %%
df
# Out:
#    BH  NI  BI  RA  PA
# 0   0   8   6   5   6
# 1   0   0   1   3   4
# 2   6   8   0   9   0
# 3   2   2   8   0   5
# 4   9   3   9   8   4

# %%
kaggle_survey_dataset.columns=kaggle_survey_dataset.iloc[0,:].values

# %%
kaggle_survey_dataset.drop(0,axis=0,inplace=True)

# %%
df.corr()
# Out:
#           BH        NI        BI        RA        PA
# BH  1.000000  0.131564  0.237014  0.701824 -0.513006
# NI  0.131564  1.000000 -0.165014  0.580561 -0.295718
# BI  0.237014 -0.165014  1.000000 -0.249750  0.665322
# RA  0.701824  0.580561 -0.249750  1.000000 -0.626601
# PA -0.513006 -0.295718  0.665322 -0.626601  1.000000

# %%
kaggle_survey_dataset
# Out:
#       Duration (in seconds) What is your age (# years)?  \
# 1                       161                       25-29
# 2                      1024                       22-24
# 3                      2176                       25-29
# 4                      1112                       45-49
# 5                       228                       22-24
# ...                     ...                         ...
# 25969                   636                       35-39
# 25970                   358                       22-24
# 25971                   391                       18-21
# 25972                   527                       25-29
# 25973                   217                       22-24
#
#       What is your gender? - Selected Choice  \
# 1                                        Man
# 2                                        Man
# 3                                        Man
# 4                                        Man
# 5                                        Man
# ...

# %%
# Out:
# 'Duration (in seconds)'

# %%
survey_time=kaggle_survey_dataset[kaggle_survey_dataset.columns[0]].values

# %%
survey_time
# Out:
# array(['161', '1024', '2176', ..., 391, 527, 217], dtype=object)

# %%
survey_time=survey_time.astype(int)

# %%
kaggle_survey_dataset.shape
# Out:
# (25973, 369)

# %%
len(survey_time)
# Out:
# 25973

# %%
survey_time
# Out:
# array([ 161, 1024, 2176, ...,  391,  527,  217])

# %%
survey_time ### minutes

# %%
survey_time_min=survey_time/60

# %%
survey_time_min
# Out:
# array([ 2.68333333, 17.06666667, 36.26666667, ...,  6.51666667,
#         8.78333333,  3.61666667])

# %%
survey_time_min.max()
# Out:
# 41477.55

# %%
survey_time_min.min()
# Out:
# 2.0

# %%
survey_time_min
# Out:
# array([ 2.68333333, 17.06666667, 36.26666667, ...,  6.51666667,
#         8.78333333,  3.61666667])

# %%
kaggle_survey_dataset[kaggle_survey_dataset.columns[0]]=kaggle_survey_dataset[kaggle_survey_dataset.columns[0]].astype(int)

# %%
kaggle_survey_dataset[kaggle_survey_dataset.columns[0]].min()
# Out:
# 120

# %%
kaggle_survey_dataset[kaggle_survey_dataset.columns[0]].max()
# Out:
# 2488653

# %%
kaggle_survey_dataset['Duration (in minutes)']=kaggle_survey_dataset[kaggle_survey_dataset.columns[0]]/60

# %%
kaggle_survey_dataset[kaggle_survey_dataset.columns[-1]].min()
# Out:
# 2.0

# %%
kaggle_survey_dataset[kaggle_survey_dataset.columns[-1]].max()
# Out:
# 41477.55

# %%
kaggle_survey_dataset[kaggle_survey_dataset.columns[-1]]=kaggle_survey_dataset[kaggle_survey_dataset.columns[-1]].astype(int)

# %%
kaggle_survey_dataset[kaggle_survey_dataset.columns[-1]].value_counts().head(10)
# Out:
# 8     1959
# 9     1854
# 7     1843
# 10    1704
# 6     1679
# 11    1497
# 5     1371
# 12    1281
# 4     1168
# 13    1086
# Name: Duration (in minutes), dtype: int64

# %%
#### 70 percent of total people who filled the survey are spending time between 4 min to 13 min
#### few people with abnormal time taken for filling the survey will be eliminated from the analysis

# %%
kaggle_survey_dataset[kaggle_survey_dataset.columns[-1]]
# Out:
# 1         2
# 2        17
# 3        36
# 4        18
# 5         3
#          ..
# 25969    10
# 25970     5
# 25971     6
# 25972     8
# 25973     3
# Name: Duration (in minutes), Length: 25973, dtype: int32
