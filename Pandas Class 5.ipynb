# %%
import pandas as pd
import numpy as np

# %%
df1=pd.DataFrame(np.random.randint(0,10,(5,3)))
df2=pd.DataFrame(np.random.randint(0,10,(4,3)))

# %%
df2
# Out:
#    0  1  2
# 0  2  4  2
# 1  4  9  1
# 2  3  8  8
# 3  3  2  3

# %%
df1
# Out:
#    0  1  2
# 0  7  5  7
# 1  9  8  8
# 2  9  8  7
# 3  9  6  5
# 4  1  2  3

# %%
df2
# Out:
#    0  1  2
# 0  2  4  2
# 1  4  9  1
# 2  3  8  8
# 3  3  2  3

# %%
pd.concat([df1,df2],axis=1)  #### Append
#### Axis=0  ### concat at the bottom
#### Axis=1  ### concat at the right side
#### concat joining based on index
# Out:
#    0  1  2    0    1    2
# 0  7  5  7  2.0  4.0  2.0
# 1  9  8  8  4.0  9.0  1.0
# 2  9  8  7  3.0  8.0  8.0
# 3  9  6  5  3.0  2.0  3.0
# 4  1  2  3  NaN  NaN  NaN

# %%
df1
# Out:
#    0  1  2
# 0  7  5  7
# 1  9  8  8
# 2  9  8  7
# 3  9  6  5
# 4  1  2  3

# %%
df2
# Out:
#    0  1  2
# 0  2  4  2
# 1  4  9  1
# 2  3  8  8
# 3  3  2  3

# %%
df1.append(df2) ### concat with axis=0
# Out:
#    0  1  2
# 0  7  5  7
# 1  9  8  8
# 2  9  8  7
# 3  9  6  5
# 4  1  2  3
# 0  2  4  2
# 1  4  9  1
# 2  3  8  8
# 3  3  2  3

# %%
import pandas as pd
import numpy as np
##### version compatability : ignore all the warnings in the jupyter notebook
import warnings
warnings.filterwarnings("ignore")

# %%
kaggle_survey_dataset=pd.read_csv("D:/ML LABS 2.0/datasets/kaggle_survey_2021_responses.csv")

# %%
kaggle_survey_dataset.head(2)
# Out:
#                       zr                           Q1  \
# 0  Duration (in seconds)  What is your age (# years)?
# 1                    161                        25-29
#
#                                        Q2  \
# 0  What is your gender? - Selected Choice
# 1                                     Man
#
#                                           Q3  \
# 0  In which country do you currently reside?
# 1                                    Algeria
#
#                                                   Q4  \
# 0  What is the highest level of formal education ...
# 1                             Professional doctorate
#
#                                                   Q5  \
# 0  Select the title most similar to your current ...
# 1                                            Student
#
#                                                   Q6  \
# 0  For how many years have you been writing code ...
# 1                          I have never written code
#
# ...

# %%
### Preprocessing ### the objective : to make an effective dataset : input to the algorithm
### EDA :
### Model Development ### Algorithm
### Model Validation
### Model Deployment

# %%
#### label encoders
#### Dummy variables

# %%
kaggle_survey_dataset
# Out:
#                           zr                           Q1  \
# 0      Duration (in seconds)  What is your age (# years)?
# 1                        161                        25-29
# 2                       1024                        22-24
# 3                       2176                        25-29
# 4                       1112                        45-49
# ...                      ...                          ...
# 25969                    636                        35-39
# 25970                    358                        22-24
# 25971                    391                        18-21
# 25972                    527                        25-29
# 25973                    217                        22-24
#
#                                            Q2  \
# 0      What is your gender? - Selected Choice
# 1                                         Man
# 2                                         Man
# 3                                         Man
# ...

# %%
kaggle_survey_dataset.columns=kaggle_survey_dataset.iloc[0,:].values

# %%
kaggle_survey_dataset.drop(0,axis=0,inplace=True)

# %%
kaggle_survey_dataset.head()
# Out:
#   Duration (in seconds) What is your age (# years)?  \
# 1                   161                       25-29
# 2                  1024                       22-24
# 3                  2176                       25-29
# 4                  1112                       45-49
# 5                   228                       22-24
#
#   What is your gender? - Selected Choice  \
# 1                                    Man
# 2                                    Man
# 3                                    Man
# 4                                    Man
# 5                                    Man
#
#   In which country do you currently reside?  \
# 1                                   Algeria
# 2                                   Algeria
# 3                                   Algeria
# 4                                   Algeria
# 5                                   Algeria
#
#   What is the highest level of formal education that you have attained or plan to attain within the next 2 years?  \
# ...

# %%
kaggle_survey_dataset[kaggle_survey_dataset.columns[0]]=kaggle_survey_dataset[kaggle_survey_dataset.columns[0]].astype(int)

# %%
kaggle_survey_dataset[kaggle_survey_dataset.columns[0]].min()
# Out:
# 120

# %%
kaggle_survey_dataset[kaggle_survey_dataset.columns[0]].max()
# Out:
# 2488653

# %%
kaggle_survey_dataset['Duration (in minutes)']=kaggle_survey_dataset[kaggle_survey_dataset.columns[0]]/60

# %%
kaggle_survey_dataset[kaggle_survey_dataset.columns[-1]].min()
# Out:
# 2.0

# %%
kaggle_survey_dataset[kaggle_survey_dataset.columns[-1]].max()
# Out:
# 41477.55

# %%
kaggle_survey_dataset[kaggle_survey_dataset.columns[-1]]=kaggle_survey_dataset[kaggle_survey_dataset.columns[-1]].astype(int)

# %%
kaggle_survey_dataset[kaggle_survey_dataset.columns[2]].head(40)
# Out:
# 1       Man
# 2       Man
# 3       Man
# 4       Man
# 5       Man
# 6       Man
# 7       Man
# 8       Man
# 9       Man
# 10      Man
# 11      Man
# 12      Man
# 13      Man
# 14      Man
# 15      Man
# 16      Man
# 17      Man
# 18      Man
# 19      Man
# 20      Man
# 21      Man
# 22      Man
# 23      Man
# 24      Man
# 25      Man
# 26      Man
# 27      Man
# 28      Man
# 29      Man
# 30      Man
# 31      Man
# 32      Man
# 33    Woman
# 34    Woman
# 35    Woman
# 36    Woman
# 37    Woman
# 38    Woman
# 39    Woman
# 40    Woman
# Name: What is your gender? - Selected Choice, dtype: object

# %%
kaggle_survey_dataset
# Out:
#        Duration (in seconds) What is your age (# years)?  \
# 1                        161                       25-29
# 2                       1024                       22-24
# 3                       2176                       25-29
# 4                       1112                       45-49
# 5                        228                       22-24
# ...                      ...                         ...
# 25969                    636                       35-39
# 25970                    358                       22-24
# 25971                    391                       18-21
# 25972                    527                       25-29
# 25973                    217                       22-24
#
#       What is your gender? - Selected Choice  \
# 1                                        Man
# 2                                        Man
# 3                                        Man
# 4                                        Man
# 5                                        Man
# ...

# %%
#### Cross tables

# %%
pd.crosstab(kaggle_survey_dataset[kaggle_survey_dataset.columns[1],kaggle_survey_dataset[kaggle_survey_dataset.columns[2]]])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-f56028afc872> in <module>
# ----> 1 pd.crosstab(kaggle_survey_dataset[kaggle_survey_dataset.columns[1],kaggle_survey_dataset[kaggle_survey_dataset.columns[2]]])
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3078             casted_key = self._maybe_cast_indexer(key)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# ...

# %%
kaggle_survey_dataset[kaggle_survey_dataset.columns[1]].count()
# Out:
# 25973

# %%
kaggle_survey_dataset[kaggle_survey_dataset.columns[2]].count()
# Out:
# 25973

# %%
pd.crosstab(kaggle_survey_dataset[kaggle_survey_dataset.columns[1]],kaggle_survey_dataset[kaggle_survey_dataset.columns[2]])
# Out:
# What is your gender? - Selected Choice   Man  Nonbinary  Prefer not to say  \
# What is your age (# years)?
# 18-21                                   3696         16                 60
# 22-24                                   3643         13                 66
# 25-29                                   3859         12                 61
# 30-34                                   2765         17                 34
# 35-39                                   1993          7                 42
# 40-44                                   1537          4                 31
# 45-49                                   1171          4                 24
# 50-54                                    811          3                 14
# 55-59                                    509          4                  7
# 60-69                                    504          4                 10
# 70+                                      110          4                  6
#
# ...

# %%
kaggle_survey_dataset[kaggle_survey_dataset.columns[1]].groupby(kaggle_survey_dataset[kaggle_survey_dataset.columns[2]]).count()
# Out:
# What is your gender? - Selected Choice
# Man                        20598
# Nonbinary                     88
# Prefer not to say            355
# Prefer to self-describe       42
# Woman                       4890
# Name: What is your age (# years)?, dtype: int64

# %%
#####  Database
##### Timeseries Data
